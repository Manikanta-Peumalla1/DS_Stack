# %%
! pip install ucimlrepo
# Out:
# Collecting ucimlrepo
#   Downloading ucimlrepo-0.0.7-py3-none-any.whl (8.0 kB)
# Requirement already satisfied: pandas>=1.0.0 in c:\users\mk perumalla\anaconda3\lib\site-packages (from ucimlrepo) (1.5.3)
# Requirement already satisfied: certifi>=2020.12.5 in c:\users\mk perumalla\anaconda3\lib\site-packages (from ucimlrepo) (2025.10.5)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\mk perumalla\anaconda3\lib\site-packages (from pandas>=1.0.0->ucimlrepo) (1.23.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\mk perumalla\anaconda3\lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mk perumalla\anaconda3\lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2022.7)
# Requirement already satisfied: six>=1.5 in c:\users\mk perumalla\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas>=1.0.0->ucimlrepo) (1.16.0)
# Installing collected packages: ucimlrepo
# Successfully installed ucimlrepo-0.0.7

# %%
! pip install python-dotenv
# Out:
# Collecting python-dotenv
#   Downloading python_dotenv-1.2.1-py3-none-any.whl (21 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.2.1

# %% [markdown]
# ### Logistic_Regression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sms
import sqlalchemy
from dotenv import load_dotenv

# %%
engine = sqlalchemy.create_engine("mysql+pymysql://{user}:{pw}@localhost/{db}"
                       .format(user = "root",    # user
                               pw = "mani-123",      # passwrd
                               db = "MLModel")) # database
